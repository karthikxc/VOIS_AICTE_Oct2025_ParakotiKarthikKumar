# %% [markdown]
# ### Author: Parakoti Karthik Kumar

# %% [markdown]
# ### Created On: 29-09-2025

# %% [markdown]
# ### About Dataset
#
# ### Context
# The dataset contains detailed information about Airbnb listings, hosts, and booking activities. It provides insights into pricing, availability, host activity, and property details across different neighborhoods and property types. This dataset can be used to analyze trends in the short-term rental market, understand customer preferences, and perform exploratory data analysis for hospitality and tourism research.
#
# ### Source
# This dataset was compiled from Airbnb’s publicly available listing information. It includes host details, property characteristics, reviews, and availability data for different locations.
#
# ### Data fields
# id - Unique identifier for each listing
#
# NAME - Name/title of the Airbnb listing
#
# host id - Unique identifier for the host
#
# host_identity_verified -Whether the hosts identity is verified (yes/no)
#
# host name - Name of the host
#
# neighbourhood group - Major geographical area (e.g., Brooklyn, Manhattan)
#
# neighbourhood - Specific neighborhood where the property is located
#
# lat- Latitude of the listing
#
# long- Longitude of the listing
#
# country- Country of the listing
#
# country code- ISO country code
#
# instant_bookable- Whether the property allows instant booking
#
# cancellation_policy- Type of cancellation policy applied
#
# room type- Type of room offered (Entire home/apt, Private room, Shared room)
#
# Construction year- Year the property was constructed
#
# price- Price per night (USD)
#
# service fee- Service fee charged
#
# minimum nights- Minimum number of nights required to book
#
# number of reviews- Total reviews received
#
# last review- Date of the most recent review
#
# reviews per month- Average number of reviews per month
#
# review rate number- Average rating value from guests
#
# calculated host listings count- Number of listings the host manages
#
# availability 365-Number of available days in a year
#
# house_rules- Special rules provided by the host
#
# license- License information (if applicable)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("/content/1730285881-Airbnb_Open_Data (1).xlsx")
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee  minimum nights  \
# ...

# %%
print("Shape of the Dataset:",df.shape)
# Out:
# Shape of the Dataset: (102599, 26)

# %%
print("No.of Rows in the Dataset:",df.shape[0])
# Out:
# No.of Rows in the Dataset: 102599

# %%
print("No.of Columns in the Dataset:",df.shape[1])
# Out:
# No.of Columns in the Dataset: 26

# %%
print("The size of the Dataset:",df.size,"Values")
# Out:
# The size of the Dataset: 2667574 Values

# %%
print("Statistics about Numerical Columns of the Dataset:\n",df.describe())
# Out:
# Statistics about Numerical Columns of the Dataset:
#                   id       host id            lat           long  \
# count  1.025990e+05  1.025990e+05  102591.000000  102591.000000
# mean   2.914623e+07  4.925411e+10      40.728094     -73.949644
# min    1.001254e+06  1.236005e+08      40.499790     -74.249840
# 25%    1.508581e+07  2.458333e+10      40.688740     -73.982580
# 50%    2.913660e+07  4.911774e+10      40.722290     -73.954440
# 75%    4.320120e+07  7.399650e+10      40.762760     -73.932350
# max    5.736742e+07  9.876313e+10      40.916970     -73.705220
# std    1.625751e+07  2.853900e+10       0.055857       0.049521
#
#        instant_bookable  Construction year          price    service fee  \
# count     102494.000000      102385.000000  102352.000000  102326.000000
# mean           0.497785        2012.487464     625.293536     125.026924
# min            0.000000        2003.000000      50.000000      10.000000
# ...

# %%
print("Column Wise Information")
df.info()
# Out:
# Column Wise Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102329 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102191 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
# ...

# %%
df.dtypes
# Out:
# id                                         int64
# NAME                                      object
# host id                                    int64
# host_identity_verified                    object
# host name                                 object
# neighbourhood group                       object
# neighbourhood                             object
# lat                                      float64
# long                                     float64
# country                                   object
# country code                              object
# instant_bookable                         float64
# cancellation_policy                       object
# room type                                 object
# Construction year                        float64
# price                                    float64
# service fee                              float64
# minimum nights                           float64
# number of reviews                        float64
# ...

# %%
df.isnull().sum()
# Out:
# id                                     0
# NAME                                 270
# host id                                0
# host_identity_verified               289
# host name                            408
# neighbourhood group                   29
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              532
# country code                         131
# instant_bookable                     105
# cancellation_policy                   76
# room type                              0
# Construction year                    214
# price                                247
# service fee                          273
# minimum nights                       409
# number of reviews                    183
# last review                        15893
# reviews per month                  15879
# review rate number                   326
# calculated host listings count       319
# ...

# %%
print("No.of Nulls present in the dataset:",df.isnull().sum().sum())
# Out:
# No.of Nulls present in the dataset: 193503

# %%
for col in df.columns:
    print(col)
# Out:
# id
# NAME
# host id
# host_identity_verified
# host name
# neighbourhood group
# neighbourhood
# lat
# long
# country
# country code
# instant_bookable
# cancellation_policy
# room type
# Construction year
# price
# service fee
# minimum nights
# number of reviews
# last review
# reviews per month
# review rate number
# calculated host listings count
# availability 365
# house_rules
# license

# %%
df.hist(bins=15,figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'host id'}>,
#         <Axes: title={'center': 'lat'}>,
#         <Axes: title={'center': 'long'}>],
#        [<Axes: title={'center': 'instant_bookable'}>,
#         <Axes: title={'center': 'Construction year'}>,
#         <Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'service fee'}>],
#        [<Axes: title={'center': 'minimum nights'}>,
#         <Axes: title={'center': 'number of reviews'}>,
#         <Axes: title={'center': 'last review'}>,
#         <Axes: title={'center': 'reviews per month'}>],
#        [<Axes: title={'center': 'review rate number'}>,
#         <Axes: title={'center': 'calculated host listings count'}>,
#         <Axes: title={'center': 'availability 365'}>, <Axes: >]],
#       dtype=object)

# %%
sns.boxplot(y='price',data=df)
# Out:
# <Axes: ylabel='price'>

# %%
sns.boxplot(y='service fee',data=df)
# Out:
# <Axes: ylabel='service fee'>

# %%
sns.boxplot(y='minimum nights',data=df)
# Out:
# <Axes: ylabel='minimum nights'>

# %%
sns.boxplot(y='number of reviews',data=df)
# Out:
# <Axes: ylabel='number of reviews'>

# %%
sns.boxplot(y='reviews per month',data=df)
# Out:
# <Axes: ylabel='reviews per month'>

# %%
sns.boxplot(y='review rate number',data=df)
# Out:
# <Axes: ylabel='review rate number'>

# %%
sns.boxplot(y='calculated host listings count',data=df)
# Out:
# <Axes: ylabel='calculated host listings count'>

# %%
sns.boxplot(y='availability 365',data=df)
# Out:
# <Axes: ylabel='availability 365'>

# %%
sns.boxplot(y='lat',data=df)
# Out:
# <Axes: ylabel='lat'>

# %%
sns.boxplot(y='long',data=df)
# Out:
# <Axes: ylabel='long'>

# %%
sns.boxplot(y='Construction year',data=df)
# Out:
# <Axes: ylabel='Construction year'>

# %%
sns.boxplot(y='id',data=df)
# Out:
# <Axes: ylabel='id'>

# %%
sns.boxplot(y='host id',data=df)
# Out:
# <Axes: ylabel='host id'>

# %%
def remove_outlier(series):
    sorted(series)
    Q1,Q3 = series.quantile([0.25,0.75])
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return lower_bound, upper_bound

# %%
low, high = remove_outlier(df['price'])

# %%
df['price'] = np.where(df['price']>high,high,df['price'])

# %%
df['price'] = np.where(df['price']<low,low,df['price'])

# %%
sns.boxplot(y='price',data=df)
# Out:
# <Axes: ylabel='price'>

# %%
low, high = remove_outlier(df['service fee'])

# %%
df['service fee'] = np.where(df['service fee']>high,high,df['service fee'])

# %%
df['service fee'] = np.where(df['service fee']<low,low,df['service fee'])

# %%
sns.boxplot(y='service fee',data=df)
# Out:
# <Axes: ylabel='service fee'>

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
low, high = remove_outlier(df['minimum nights'])

# %%
df['minimum nights'] = np.where(df['minimum nights']>high,high,df['minimum nights'])

# %%
df['minimum nights'] = np.where(df['minimum nights']<low,low,df['minimum nights'])

# %%
sns.boxplot(y='minimum nights',data=df)
# Out:
# <Axes: ylabel='minimum nights'>

# %%
low, high = remove_outlier(df['number of reviews'])

# %%
df['number of reviews'] = np.where(df['number of reviews']>high,high,df['number of reviews'])

# %%
df['number of reviews'] = np.where(df['number of reviews']<low,low,df['number of reviews'])

# %%
sns.boxplot(y='number of reviews',data=df)
# Out:
# <Axes: ylabel='number of reviews'>

# %%
low, high = remove_outlier(df['reviews per month'])

# %%
df['reviews per month'] = np.where(df['reviews per month']>high,high,df['reviews per month'])

# %%
df['reviews per month'] = np.where(df['reviews per month']<low,low,df['reviews per month'])

# %%
sns.boxplot(y='reviews per month',data=df)
# Out:
# <Axes: ylabel='reviews per month'>

# %%
low, high = remove_outlier(df['review rate number'])

# %%
df['review rate number'] = np.where(df['review rate number']>high,high,df['review rate number'])

# %%
df['review rate number'] = np.where(df['review rate number']<low,low,df['review rate number'])

# %%
sns.boxplot(y='review rate number',data=df)
# Out:
# <Axes: ylabel='review rate number'>

# %%
low, high = remove_outlier(df['calculated host listings count'])

# %%
df['calculated host listings count'] = np.where(df['calculated host listings count']>high,high,df['calculated host listings count'])

# %%
df['calculated host listings count'] = np.where(df['calculated host listings count']<low,low,df['calculated host listings count'])

# %%
sns.boxplot(y='calculated host listings count',data=df)
# Out:
# <Axes: ylabel='calculated host listings count'>

# %%
low, high = remove_outlier(df['availability 365'])

# %%
df['availability 365'] = np.where(df['availability 365']>high,high,df['availability 365'])

# %%
df['availability 365'] = np.where(df['availability 365']<low,low,df['availability 365'])

# %%
sns.boxplot(y='availability 365',data=df)
# Out:
# <Axes: ylabel='availability 365'>

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee  minimum nights  \
# ...

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='long',y='lat',hue='neighbourhood group',data=df)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x="room type", y="price", data=df, palette="Set3")
plt.title("Violin Plot of Price by Room Type")
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipython-input-2923017746.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="room type", y="price", data=df, palette="Set3")

# %%
plt.figure(figsize=(15, 10))

# Box plot for Price
plt.subplot(3, 1, 1)
sns.boxplot(x="room type", y="price", data=df, palette="Set2")
plt.title("Box Plot of Price by Room Type")
plt.xticks(rotation=90)

# Box plot for Minimum Nights
plt.subplot(3, 1, 2)
sns.boxplot(x="room type", y="minimum nights", data=df, palette="Set2")
plt.title("Box Plot of Minimum Nights by Room Type")
plt.xticks(rotation=90)

# Box plot for Number of Reviews
plt.subplot(3, 1, 3)
sns.boxplot(x="room type", y="number of reviews", data=df, palette="Set2")
plt.title("Box Plot of Number of Reviews by Room Type")
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-778115357.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="room type", y="price", data=df, palette="Set2")
# /tmp/ipython-input-778115357.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="room type", y="minimum nights", data=df, palette="Set2")
# /tmp/ipython-input-778115357.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="room type", y="number of reviews", data=df, palette="Set2")

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='room type', y='price', data=df, estimator=np.mean, palette="Set2")
plt.title("Average Price by Room Type")
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipython-input-3601200161.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='room type', y='price', data=df, estimator=np.mean, palette="Set2")

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='neighbourhood group', y='number of reviews', data=df, estimator=np.mean, palette="Set3")
plt.title("Average Number of Reviews by Neighbourhood Group")
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipython-input-2600259234.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='neighbourhood group', y='number of reviews', data=df, estimator=np.mean, palette="Set3")

# %%
df.groupby(['room type'])['price'].mean().sort_values(ascending=False)
# Out:
# room type
# Hotel room         668.465517
# Shared room        634.132101
# Entire home/apt    625.082232
# Private room       625.007363
# Name: price, dtype: float64

# %%
df.groupby(['neighbourhood group'])['number of reviews'].mean().sort_values(ascending=False)
# Out:
# neighbourhood group
# manhatan         73.500000
# brookln          73.500000
# Staten Island    27.661780
# Bronx            24.151180
# Queens           23.648208
# Brooklyn         20.870045
# Manhattan        17.698717
# Name: number of reviews, dtype: float64

# %%
df.groupby(['cancellation_policy'])['availability 365'].mean().sort_values(ascending=False)
# Out:
# cancellation_policy
# strict      141.604252
# flexible    141.074245
# moderate    140.537946
# Name: availability 365, dtype: float64
